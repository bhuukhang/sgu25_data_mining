# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("master_data.csv")
df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 110007  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 110008  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 110009  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 110010  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 110011  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 0         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1         delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2         delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3         delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4         delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...             ...                      ...                  ...
# 110007    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 110008    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 110009    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 110010    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 110011    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0               2017-10-04 19:55:00           2017-10-10 21:25:13
# 1               2018-07-26 14:31:00           2018-08-07 15:27:45
# 2               2018-08-08 13:50:00           2018-08-17 18:06:29
# 3               2017-11-22 13:39:59           2017-12-02 00:28:42
# 4               2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                             ...                           ...
# 110007          2018-02-07 23:22:42           2018-02-28 17:37:56
# 110008          2017-08-28 20:52:26           2017-09-21 11:24:17
# 110009          2018-01-12 15:35:03           2018-01-25 23:32:54
# 110010          2018-01-12 15:35:03           2018-01-25 23:32:54
# 110011          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#        order_estimated_delivery_date  order_item_id  \
# 0                         2017-10-18            1.0
# 1                         2018-08-13            1.0
# 2                         2018-09-04            1.0
# 3                         2017-12-15            1.0
# 4                         2018-02-26            1.0
# ...                              ...            ...
# 110007                    2018-03-02            1.0
# 110008                    2017-09-27            1.0
# 110009                    2018-02-15            1.0
# 110010                    2018-02-15            2.0
# 110011                    2018-04-03            1.0
#
#                               product_id  ... customer_state  \
# 0       87285b34884572647811a353c7ac498a  ...             SP
# 1       595fac2a385ac33a80bd5114aec74eb8  ...             BA
# 2       aa4383b373c6aca5d8797843e5594415  ...             GO
# 3       d0b61bfb1de832b15ba9d266ca96e5b0  ...             RN
# 4       65266b2da20d04dbe00c5c2d3bb7859e  ...             SP
# ...                                  ...  ...            ...
# 110007  f1d4ce8c6dd66c47bbaa8c6781c2a923  ...             SP
# 110008  b80910977a37536adeddd63663f916ad  ...             BA
# 110009  d1c427060a0f73f6b889a5c7c61f2ac4  ...             RJ
# 110010  d1c427060a0f73f6b889a5c7c61f2ac4  ...             RJ
# 110011  006619bbed68b000c8ba3f8725d5409e  ...             PR
#
#                                review_id  review_score  review_comment_title  \
# 0       a54f0611adc9ed256b57ede6b6eb5114           4.0                   NaN
# 1       8d5266042046a06655c8db133d120ba5           4.0      Muito boa a loja
# 2       e73b67b67587f7644d5bd1a52deb1b01           5.0                   NaN
# 3       359d03e676b3c069f62cadba8dd3f6e8           5.0                   NaN
# 4       e50934924e227544ba8246aeb3770dd4           5.0                   NaN
# ...                                  ...           ...                   ...
# 110007  29bb71b2760d0f876dfa178a76bc4734           4.0                   NaN
# 110008  371579771219f6db2d830d50805977bb           5.0                   NaN
# 110009  8ab6855b9fe9b812cd03a480a25058a1           2.0                   NaN
# 110010  8ab6855b9fe9b812cd03a480a25058a1           2.0                   NaN
# 110011  dc9c59b4688062c25758c2be4cafc523           5.0                   NaN
#
#                                    review_comment_message  \
# 0       Não testei o produto ainda, mas ele veio corre...
# 1                                    Muito bom o produto.
# 2                                                     NaN
# 3       O produto foi exatamente o que eu esperava e e...
# 4                                                     NaN
# ...                                                   ...
# 110007       So uma peça que veio rachado mas tudo bem rs
# 110008                       Foi entregue antes do prazo.
# 110009  Foi entregue somente 1. Quero saber do outro p...
# 110010  Foi entregue somente 1. Quero saber do outro p...
# 110011                                                NaN
#
#         review_creation_date  review_answer_timestamp  delivery_days  is_late  \
# 0        2017-10-11 00:00:00      2017-10-12 03:43:48              8        0
# 1        2018-08-08 00:00:00      2018-08-08 18:37:50             13        0
# 2        2018-08-18 00:00:00      2018-08-22 19:07:58              9        0
# 3        2017-12-03 00:00:00      2017-12-05 19:21:58             13        0
# 4        2018-02-17 00:00:00      2018-02-18 13:02:51              2        0
# ...                      ...                      ...            ...      ...
# 110007   2018-03-01 00:00:00      2018-03-02 17:50:01             22        0
# 110008   2017-09-22 00:00:00      2017-09-22 23:10:57             24        0
# 110009   2018-01-26 00:00:00      2018-01-27 09:16:56             17        0
# 110010   2018-01-26 00:00:00      2018-01-27 09:16:56             17        0
# 110011   2018-03-17 00:00:00      2018-03-17 16:33:31              7        0
#
#         review_binary
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 110007              1
# 110008              1
# 110009              0
# 110010              0
# 110011              1
#
# [110012 rows x 35 columns]

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  order_item_id  \
# 0                    2017-10-18            1.0
# 1                    2018-08-13            1.0
# 2                    2018-09-04            1.0
# 3                    2017-12-15            1.0
# 4                    2018-02-26            1.0
#
#                          product_id  ... customer_state  \
# 0  87285b34884572647811a353c7ac498a  ...             SP
# 1  595fac2a385ac33a80bd5114aec74eb8  ...             BA
# 2  aa4383b373c6aca5d8797843e5594415  ...             GO
# 3  d0b61bfb1de832b15ba9d266ca96e5b0  ...             RN
# 4  65266b2da20d04dbe00c5c2d3bb7859e  ...             SP
#
#                           review_id  review_score  review_comment_title  \
# 0  a54f0611adc9ed256b57ede6b6eb5114           4.0                   NaN
# 1  8d5266042046a06655c8db133d120ba5           4.0      Muito boa a loja
# 2  e73b67b67587f7644d5bd1a52deb1b01           5.0                   NaN
# 3  359d03e676b3c069f62cadba8dd3f6e8           5.0                   NaN
# 4  e50934924e227544ba8246aeb3770dd4           5.0                   NaN
#
#                               review_comment_message  review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...   2017-10-11 00:00:00
# 1                               Muito bom o produto.   2018-08-08 00:00:00
# 2                                                NaN   2018-08-18 00:00:00
# 3  O produto foi exatamente o que eu esperava e e...   2017-12-03 00:00:00
# 4                                                NaN   2018-02-17 00:00:00
#
#    review_answer_timestamp  delivery_days  is_late  review_binary
# 0      2017-10-12 03:43:48              8        0              1
# 1      2018-08-08 18:37:50             13        0              1
# 2      2018-08-22 19:07:58              9        0              1
# 3      2017-12-05 19:21:58             13        0              1
# 4      2018-02-18 13:02:51              2        0              1
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110012 entries, 0 to 110011
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       110012 non-null  object
#  1   customer_id                    110012 non-null  object
#  2   order_status                   110012 non-null  object
#  3   order_purchase_timestamp       110012 non-null  object
#  4   order_approved_at              109997 non-null  object
#  5   order_delivered_carrier_date   110011 non-null  object
#  6   order_delivered_customer_date  110012 non-null  object
#  7   order_estimated_delivery_date  110012 non-null  object
#  8   order_item_id                  110012 non-null  float64
#  9   product_id                     110012 non-null  object
#  10  seller_id                      110012 non-null  object
#  11  shipping_limit_date            110012 non-null  object
#  12  price                          110012 non-null  float64
#  13  freight_value                  110012 non-null  float64
#  14  product_category_name          108457 non-null  object
#  15  product_name_lenght            108479 non-null  float64
#  16  product_description_lenght     108479 non-null  float64
#  17  product_photos_qty             108479 non-null  float64
#  18  product_weight_g               109994 non-null  float64
#  19  product_length_cm              109994 non-null  float64
#  20  product_height_cm              109994 non-null  float64
#  21  product_width_cm               109994 non-null  float64
#  22  customer_unique_id             110012 non-null  object
#  23  customer_zip_code_prefix       110012 non-null  int64
#  24  customer_city                  110012 non-null  object
#  25  customer_state                 110012 non-null  object
#  26  review_id                      110012 non-null  object
#  27  review_score                   110012 non-null  float64
#  28  review_comment_title           13126 non-null   object
#  29  review_comment_message         46137 non-null   object
#  30  review_creation_date           110012 non-null  object
#  31  review_answer_timestamp        110012 non-null  object
#  32  delivery_days                  110012 non-null  int64
#  33  is_late                        110012 non-null  int64
#  34  review_binary                  110012 non-null  int64
# dtypes: float64(11), int64(4), object(20)
# memory usage: 29.4+ MB

# %%
df = df[df['order_status'] == 'delivered']

# %%
cols = [
    'delivery_days', 'is_late',
    'product_category_name', 'price', 'product_weight_g',
    'freight_value',
    'customer_state',
    'review_binary'
]
df = df[cols]

# %%
df['product_category_name'].fillna('Unknown', inplace=True)
df['product_weight_g'].fillna(df['product_weight_g'].median(), inplace=True)
# Out:
# C:\Users\biena\AppData\Local\Temp\ipykernel_19644\437226693.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['product_category_name'].fillna('Unknown', inplace=True)
# C:\Users\biena\AppData\Local\Temp\ipykernel_19644\437226693.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['product_weight_g'].fillna(df['product_weight_g'].median(), inplace=True)

# %%
df['delivery_speed'] = pd.cut(
    df['delivery_days'],
    bins=[0,3,7,100],
    labels=['Fast', 'Normal', 'Slow']
)

# %%
df['price_level'] = pd.qcut(
    df['price'],
    q=3,
    labels=['Cheap', 'Medium', 'Expensive']
)

# %%
df['weight_level'] = pd.qcut(
    df['product_weight_g'],
    q=3,
    labels=['Light', 'Medium', 'Heavy']
)

# %%
df['freight_level'] = pd.qcut(
    df['freight_value'],
    q=3,
    labels=['Low', 'Medium', 'High']
)

# %%
df['late_item'] = df['is_late'].map({1: 'Late_delivery', 0: 'On_time_delivery'})
df['review_item'] = df['review_binary'].map({1: 'Positive_review', 0: 'Negative_review'})
df['state_item'] = 'State_' + df['customer_state']
df['category_item'] = 'Category_' + df['product_category_name'].astype(str)

# %%
transactions = df[[
    'late_item',
    'delivery_speed',
    'price_level',
    'weight_level',
    'freight_level',
    'state_item',
    'category_item',
    'review_item'
]].values.tolist()

# %%
transactions
# Out:
# [['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'High',
#   'State_BA',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_GO',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'High',
#   'State_RN',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_PR',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_RJ',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_RS',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_office_furniture',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_garden_tools',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_garden_tools',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_SP',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_MG',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_SP',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_GO',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_SC',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_BA',
#   'Category_telephony',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_electronics',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SC',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_stationery',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_RJ',
#   'Category_cool_stuff',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_baby',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'High',
#   'State_BA',
#   'Category_baby',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'High',
#   'State_RR',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_baby',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'High',
#   'State_PE',
#   'Category_air_conditioning',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_RJ',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_perfumery',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'High',
#   'State_TO',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'High',
#   'State_CE',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_SP',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_PE',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'High',
#   'State_DF',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'High',
#   'State_BA',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_RJ',
#   'Category_garden_tools',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_BA',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_RS',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_SP',
#   'Category_books_general_interest',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_construction_tools_construction',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_small_appliances',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_RS',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_RS',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Medium',
#   'State_RJ',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_RJ',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_small_appliances',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'High',
#   'State_SE',
#   'Category_telephony',
#   'Negative_review'],
#  ['Late_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'High',
#   'State_SE',
#   'Category_telephony',
#   'Negative_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_SP',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_DF',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_RJ',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_MG',
#   'Category_food',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Heavy',
#   'Low',
#   'State_MG',
#   'Category_luggage_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_construction_tools_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_construction_tools_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_MG',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_construction_tools_construction',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_SC',
#   'Category_food',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_air_conditioning',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_MG',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_MT',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_MT',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_RS',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_DF',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_MG',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RS',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'High',
#   'State_PB',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_office_furniture',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_SC',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_SP',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_fashion_underwear_beach',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_MG',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_PR',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'High',
#   'State_MG',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'High',
#   'State_SC',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'High',
#   'State_CE',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Medium',
#   'State_RJ',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_PR',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['Late_delivery',
#   'Fast',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_RS',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_MG',
#   'Category_Unknown',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_MG',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_housewares',
#   'Negative_review'],
#  ['Late_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_RJ',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_RJ',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_DF',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_DF',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_RS',
#   'Category_fashion_bags_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_RJ',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'High',
#   'State_RN',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_RJ',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_RJ',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_office_furniture',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_office_furniture',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_musical_instruments',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_PB',
#   'Category_office_furniture',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_RJ',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_MG',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Medium',
#   'Low',
#   'State_RJ',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_PR',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_PR',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_MG',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_luggage_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_GO',
#   'Category_perfumery',
#   'Negative_review'],
#  ['Late_delivery',
#   'Slow',
#   'Cheap',
#   'Heavy',
#   'Medium',
#   'State_MG',
#   'Category_garden_tools',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'High',
#   'State_PA',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_RS',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'High',
#   'State_MT',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'High',
#   'State_MT',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_books_technical',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RS',
#   'Category_toys',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Light',
#   'Medium',
#   'State_RS',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Medium',
#   'High',
#   'State_SP',
#   'Category_small_appliances',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Medium',
#   'High',
#   'State_PR',
#   'Category_food',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'High',
#   'State_RO',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RS',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Heavy',
#   'Medium',
#   'State_DF',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Medium',
#   'State_SC',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'High',
#   'State_SP',
#   'Category_books_technical',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_costruction_tools_garden',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_office_furniture',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_home_appliances',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_market_place',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_home_appliances',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Medium',
#   'State_MG',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_PR',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MT',
#   'Category_agro_industry_and_commerce',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_MG',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_Unknown',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_MT',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_PR',
#   'Category_party_supplies',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'High',
#   'State_MG',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_home_confort',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_MG',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_MG',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_ES',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_RS',
#   'Category_cds_dvds_musicals',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_RS',
#   'Category_cds_dvds_musicals',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_SP',
#   'Category_telephony',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_RJ',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_RS',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SC',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SC',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_MG',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_GO',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_GO',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_RS',
#   'Category_market_place',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_AP',
#   'Category_telephony',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_SC',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_fashion_bags_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'High',
#   'State_PE',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_MG',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_PR',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RS',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_industry_commerce_and_business',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'High',
#   'State_PR',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RS',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_RJ',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_MS',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_ES',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_RJ',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_MG',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['Late_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_MG',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_MG',
#   'Category_Unknown',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_books_general_interest',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'High',
#   'State_SC',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'High',
#   'State_SC',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_MG',
#   'Category_fashion_bags_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_SP',
#   'Category_consoles_games',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_PR',
#   'Category_furniture_bedroom',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_PR',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_PR',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_MG',
#   'Category_fashion_bags_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_SC',
#   'Category_construction_tools_safety',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_RS',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_PR',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_fixed_telephony',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_auto',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'High',
#   'State_SP',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_BA',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_RJ',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_RJ',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_RJ',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_drinks',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Medium',
#   'State_RS',
#   'Category_kitchen_dining_laundry_garden_furniture',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_SP',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'High',
#   'State_RJ',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_Unknown',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_MG',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_GO',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_DF',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'High',
#   'State_PE',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_MS',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_RS',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'High',
#   'State_RJ',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'High',
#   'State_BA',
#   'Category_baby',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_books_general_interest',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_MG',
#   'Category_fashion_bags_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_ES',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_RS',
#   'Category_fashion_shoes',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'High',
#   'State_TO',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_PR',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Light',
#   'High',
#   'State_RJ',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'High',
#   'State_PE',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_home_confort',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Medium',
#   'State_RJ',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Medium',
#   'State_SP',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'High',
#   'State_MG',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_GO',
#   'Category_home_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_GO',
#   'Category_construction_tools_safety',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_GO',
#   'Category_construction_tools_safety',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_GO',
#   'Category_home_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_PA',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_PA',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'High',
#   'State_CE',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_audio',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_stationery',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_SP',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'High',
#   'State_RJ',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_DF',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_MG',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_housewares',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_MG',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_air_conditioning',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_Unknown',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SC',
#   'Category_home_appliances_2',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
# ...
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_SP',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_DF',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_PE',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'High',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_RJ',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_SP',
#   'Category_fashion_shoes',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_SP',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_PA',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_PE',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_home_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['Late_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_office_furniture',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MT',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MS',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_PE',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Medium',
#   'State_RS',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_RJ',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_auto',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_RJ',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_ES',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_ES',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_ES',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_ES',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_fashion_male_clothing',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_costruction_tools_garden',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_SP',
#   'Category_auto',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_auto',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_SC',
#   'Category_market_place',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_RS',
#   'Category_telephony',
#   'Negative_review'],
#  ['Late_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_MS',
#   'Category_garden_tools',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SC',
#   'Category_christmas_supplies',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_SP',
#   'Category_musical_instruments',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_RJ',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_TO',
#   'Category_home_confort',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_RS',
#   'Category_audio',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_auto',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_GO',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_PR',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'High',
#   'State_BA',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_BA',
#   'Category_stationery',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'High',
#   'State_MA',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'High',
#   'State_SP',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_MG',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_RJ',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Medium',
#   'State_RJ',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Light',
#   'Low',
#   'State_RJ',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_SP',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Medium',
#   'State_RS',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'High',
#   'State_BA',
#   'Category_food_drink',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Medium',
#   'State_MG',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_RS',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Light',
#   'Medium',
#   'State_SP',
#   'Category_construction_tools_safety',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_RS',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'Medium',
#   'State_MG',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_DF',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_MG',
#   'Category_musical_instruments',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_RJ',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Heavy',
#   'Low',
#   'State_PR',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Medium',
#   'Medium',
#   'State_SC',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'Medium',
#   'State_RJ',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_fashion_underwear_beach',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_RJ',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_RJ',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_PE',
#   'Category_auto',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'Medium',
#   'State_SP',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Heavy',
#   'Medium',
#   'State_MG',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Light',
#   'Medium',
#   'State_ES',
#   'Category_tablets_printing_image',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_GO',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Expensive',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Medium',
#   'Medium',
#   'Low',
#   'State_SP',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_MG',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Medium',
#   'High',
#   'State_RJ',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Medium',
#   'Medium',
#   'Medium',
#   'State_SC',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Heavy',
#   'High',
#   'State_MA',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Heavy',
#   'High',
#   'State_MA',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Fast',
#   'Cheap',
#   'Light',
#   'Low',
#   'State_SP',
#   'Category_fashion_sport',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Medium',
#   'Heavy',
#   'High',
#   'State_MG',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Heavy',
#   'Low',
#   'State_RS',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Expensive',
#   'Heavy',
#   'High',
#   'State_SP',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['Late_delivery',
#   'Slow',
#   'Expensive',
#   'Light',
#   'Medium',
#   'State_SP',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'High',
#   'State_RN',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Slow',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_DF',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Normal',
#   'Cheap',
#   'Light',
#   'Medium',
#   'State_RJ',
#   'Category_health_beauty',
#   'Positive_review'],
#  ...]

# %% [markdown]
# # 1.Những tổ hợp yếu tố liên quan đến giao hàng, đặc điểm sản phẩm, chi phí vận chuyển và khu vực khách hàng có mối liên hệ như thế nào với mức độ hài lòng của khách hàng trên nền tảng thương mại điện tử Olist?

# %% [markdown]
# ## 1.1. Hiệu suất giao hàng (thời gian giao, giao trễ hay đúng hạn) có liên hệ như thế nào với mức độ hài lòng của khách hàng?

# %%
df_g1 = df[[
    'late_item',
    'delivery_speed',
    'review_item'
]].copy()

# %%
df['delivery_speed'] = df['delivery_speed'].astype(str)
df['delivery_speed'] = 'Speed_' + df['delivery_speed']

# %%
late_review_table = pd.crosstab(
    df_g1['late_item'],
    df_g1['review_item'],
    normalize='index'
) * 100

late_review_table
# Out:
# review_item       Negative_review  Positive_review
# late_item
# Late_delivery           65.747664        34.252336
# On_time_delivery        19.604712        80.395288

# %% [markdown]
# * Đơn hàng giao trễ:
#
# Có tới 65.75% bị đánh giá tiêu cực
#
# Chỉ 34.25% đánh giá tích cực
#
# * Đơn hàng giao đúng hạn:
#
# 80.40% nhận đánh giá tích cực
#
# Chỉ 19.60% bị đánh giá tiêu cực
#
# => Hiệu suất giao hàng có mối liên hệ mạnh mẽ với mức độ hài lòng của khách hàng.
# Các đơn hàng giao trễ có xác suất nhận đánh giá tiêu cực cao hơn đáng kể so với các đơn giao đúng hạn, trong khi giao đúng hạn có xu hướng gắn liền với mức độ hài lòng cao.
#
# => giao hàng là một yếu tố cốt lõi ảnh hưởng đến sự hài lòng của khách hàng, tạo nền tảng cho việc tiếp tục phân tích các yếu tố khác như đặc điểm sản phẩm, chi phí vận chuyển và khu vực khách hàng

# %%
speed_review_table = pd.crosstab(
    df_g1['delivery_speed'],
    df_g1['review_item'],
    normalize='index'
) * 100

speed_review_table
# Out:
# review_item     Negative_review  Positive_review
# delivery_speed
# Fast                  14.618409        85.381591
# Normal                16.858424        83.141576
# Slow                  26.918326        73.081674

# %% [markdown]
# * Giao nhanh (Fast):
#
# Tỷ lệ đánh giá tích cực cao nhất (85.38%)
#
# Đánh giá tiêu cực thấp nhất
#
# * Giao bình thường (Normal):
#
# Mức độ hài lòng giảm nhẹ so với giao nhanh
#
# * Giao chậm (Slow):
#
# Tỷ lệ đánh giá tiêu cực tăng mạnh (~27%)
#
# Đánh giá tích cực giảm xuống chỉ còn 73%
#
# => Có xu hướng rõ ràng:
#
# Tốc độ giao hàng càng chậm → mức độ hài lòng càng giảm
#
# => Hiệu suất giao hàng, bao gồm cả tình trạng trễ hạn và tốc độ giao hàng, có mối liên hệ mạnh mẽ với mức độ hài lòng của khách hàng trên Olist. Các đơn hàng giao nhanh và đúng hạn có tỷ lệ đánh giá tích cực cao hơn đáng kể so với các đơn giao chậm hoặc giao trễ.

# %%
transactions_g1 = df[[
    'late_item',
    'delivery_speed',
    'review_item'
]].values.tolist()

# %%
transactions_g1
# Out:
# [['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_nan', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_nan', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Fast', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['Late_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['On_time_delivery', 'Speed_Slow', 'Negative_review'],
#  ['On_time_delivery', 'Speed_Normal', 'Positive_review'],
#  ...]

# %%
import sys
# !{sys.executable} -m pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlxtend in c:\users\biena\appdata\roaming\python\python313\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\programdata\anaconda3\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\programdata\anaconda3\lib\site-packages (from mlxtend) (2.1.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\programdata\anaconda3\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\programdata\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_array = te.fit(transactions_g1).transform(transactions_g1)

df_trans_g1 = pd.DataFrame(te_array, columns=te.columns_)

# %%
df_trans_g1
# Out:
#         Late_delivery  Negative_review  On_time_delivery  Positive_review  \
# 0               False            False              True             True
# 1               False            False              True             True
# 2               False            False              True             True
# 3               False            False              True             True
# 4               False            False              True             True
# ...               ...              ...               ...              ...
# 110000          False            False              True             True
# 110001          False            False              True             True
# 110002          False             True              True            False
# 110003          False             True              True            False
# 110004          False            False              True             True
#
#         Speed_Fast  Speed_Normal  Speed_Slow  Speed_nan
# 0            False         False        True      False
# 1            False         False        True      False
# 2            False         False        True      False
# 3            False         False        True      False
# 4             True         False       False      False
# ...            ...           ...         ...        ...
# 110000       False         False        True      False
# 110001       False         False        True      False
# 110002       False         False        True      False
# 110003       False         False        True      False
# 110004       False          True       False      False
#
# [110005 rows x 8 columns]

# %%
from mlxtend.frequent_patterns import apriori, association_rules

freq_g1 = apriori(
    df_trans_g1,
    min_support=0.05,
    use_colnames=True
)

# %%
rules_g1 = association_rules(
    freq_g1,
    metric='confidence',
    min_threshold=0.6
)

# %%
rules_g1_focus = rules_g1[
    rules_g1['consequents'].astype(str).str.contains('review')
].sort_values(by='lift', ascending=False)

# %%
rules_g1_focus[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head(10)
# Out:
#                          antecedents                          consequents  \
# 16                   (Late_delivery)        (Negative_review, Speed_Slow)
# 14       (Late_delivery, Speed_Slow)                    (Negative_review)
# 0                    (Late_delivery)                    (Negative_review)
# 21                      (Speed_Fast)  (On_time_delivery, Positive_review)
# 10                      (Speed_Fast)                    (Positive_review)
# 24                    (Speed_Normal)  (On_time_delivery, Positive_review)
# 19    (On_time_delivery, Speed_Fast)                    (Positive_review)
# 22  (On_time_delivery, Speed_Normal)                    (Positive_review)
# 11                    (Speed_Normal)                    (Positive_review)
# 4                 (On_time_delivery)                    (Positive_review)
#
#      support  confidence      lift
# 16  0.050316    0.646612  3.709547
# 14  0.050316    0.677396  2.920399
# 0   0.051161    0.657477  2.834524
# 21  0.076487    0.848271  1.144157
# 10  0.076987    0.853816  1.111672
# 24  0.215536    0.824151  1.111624
# 19  0.076487    0.853607  1.111399
# 22  0.215536    0.831726  1.082910
# 11  0.217436    0.831416  1.082506
# 4   0.741394    0.803953  1.046750

# %% [markdown]
# Khi đơn hàng giao trễ, khả năng bị đánh giá tiêu cực cao gấp ~2.8 lần so với trung bình.
#
# Giao trễ + giao chậm → nguy cơ đánh giá tiêu cực tăng gần 3 lần.
#
# Đơn hàng trễ hạn thường đi kèm giao chậm và đánh giá xấu
# → cho thấy vấn đề logistics mang tính hệ thống, không phải ngẫu nhiên.
#
# Giao đúng hạn gần như đảm bảo đánh giá tích cực.
#
# Giao nhanh làm tăng nhẹ khả năng đánh giá tích cực, nhưng không mạnh bằng tránh giao trễ.
#
# => insight:
# Trễ hạn	-> Rất mạnh (tiêu cực)
#
# Giao chậm	-> Mạnh
#
# Giao nhanh	-.> Tăng hài lòng nhẹ
#
# Giao đúng hạn -> yêu cầu bắt buộc
#
# => Kết quả luật kết hợp cho thấy việc cải thiện hiệu quả giao hàng, đặc biệt là giảm tỷ lệ giao trễ, có tác động lớn hơn đến mức độ hài lòng của khách hàng so với việc chỉ tập trung vào tăng tốc độ giao hàng.

# %% [markdown]
# ## 1.2. Đặc điểm sản phẩm có làm thay đổi mức độ ảnh hưởng của các yếu tố giao hàng đến sự hài lòng của khách hàng hay không?

# %%
cols_g2 = [
    'late_item',          # giao hàng trễ / đúng hạn
    'delivery_speed',     # tốc độ giao hàng
    'weight_level',       # đặc điểm sản phẩm
    'price_level',
    'category_item',
    'review_item'         # mức độ hài lòng
]

df_g2 = df[cols_g2].copy()

# %%
df_g2 = df_g2.astype(str)

# %%
df_g2.isna().sum()
# Out:
# late_item         0
# delivery_speed    0
# weight_level      0
# price_level       0
# category_item     0
# review_item       0
# dtype: int64

# %%
transactions_g2 = df_g2.values.tolist()

# %%
transactions_g2
# Out:
# [['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_office_furniture',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_garden_tools',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_garden_tools',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_telephony',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_electronics',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_stationery',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_cool_stuff',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_baby',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_baby',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_baby',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_air_conditioning',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_garden_tools',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_books_general_interest',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_construction_tools_construction',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_small_appliances',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_small_appliances',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Negative_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Negative_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_food',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Expensive',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Expensive',
#   'Category_luggage_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_construction_tools_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_construction_tools_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_construction_tools_construction',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_food',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_air_conditioning',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Medium',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Medium',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_office_furniture',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_fashion_underwear_beach',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Expensive',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_Unknown',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_housewares',
#   'Negative_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_fashion_bags_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Medium',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_office_furniture',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_office_furniture',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_musical_instruments',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_office_furniture',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Cheap',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Cheap',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_luggage_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_perfumery',
#   'Negative_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_garden_tools',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_books_technical',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_toys',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Expensive',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Cheap',
#   'Category_small_appliances',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_food',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_books_technical',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Cheap',
#   'Category_costruction_tools_garden',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_office_furniture',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_home_appliances',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_market_place',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Cheap',
#   'Category_home_appliances',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_agro_industry_and_commerce',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_Unknown',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_party_supplies',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_home_confort',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_cds_dvds_musicals',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_cds_dvds_musicals',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_telephony',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Medium',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_market_place',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_telephony',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_fashion_bags_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Medium',
#   'Category_industry_commerce_and_business',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_construction_tools_lights',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['Late_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_Unknown',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_books_general_interest',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_fashion_bags_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_consoles_games',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_furniture_bedroom',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_fashion_bags_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Cheap',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_construction_tools_safety',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Medium',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_fixed_telephony',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_auto',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Cheap',
#   'Category_drinks',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_kitchen_dining_laundry_garden_furniture',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_Unknown',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_baby',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_books_general_interest',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_fashion_bags_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_fashion_shoes',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_home_confort',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_home_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_construction_tools_safety',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_construction_tools_safety',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_home_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Medium',
#   'Category_audio',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_stationery',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Expensive',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_housewares',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Expensive',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_air_conditioning',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_Unknown',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_home_appliances_2',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Expensive',
#   'Category_small_appliances',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_office_furniture',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_construction_tools_construction',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_construction_tools_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_telephony',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
# ...
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_home_appliances_2',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_luggage_accessories',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_fashion_bags_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_fashion_shoes',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_home_construction',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_office_furniture',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_auto',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_fashion_male_clothing',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_costruction_tools_garden',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Expensive',
#   'Category_perfumery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_auto',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_auto',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_market_place',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Negative_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_garden_tools',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_christmas_supplies',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_musical_instruments',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_toys',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_home_confort',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_audio',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_auto',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Heavy',
#   'Expensive',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_stationery',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_stationery',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_furniture_decor',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_computers_accessories',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_baby',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_health_beauty',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_food_drink',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_telephony',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_electronics',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Expensive',
#   'Category_construction_tools_safety',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Cheap',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_garden_tools',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_musical_instruments',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Medium',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_bed_bath_table',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Cheap',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_fashion_underwear_beach',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_auto',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_sports_leisure',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Medium',
#   'Category_tablets_printing_image',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Expensive',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Medium',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Medium',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Medium',
#   'Category_sports_leisure',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Heavy',
#   'Expensive',
#   'Category_health_beauty',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Medium',
#   'Expensive',
#   'Category_watches_gifts',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Medium',
#   'Medium',
#   'Category_auto',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_pet_shop',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Light',
#   'Cheap',
#   'Category_fashion_sport',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Medium',
#   'Category_housewares',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Cheap',
#   'Category_furniture_decor',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Heavy',
#   'Expensive',
#   'Category_cool_stuff',
#   'Positive_review'],
#  ['Late_delivery',
#   'Speed_Slow',
#   'Light',
#   'Expensive',
#   'Category_watches_gifts',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_computers_accessories',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Light',
#   'Cheap',
#   'Category_housewares',
#   'Negative_review'],
#  ['On_time_delivery',
#   'Speed_Normal',
#   'Light',
#   'Cheap',
#   'Category_health_beauty',
#   'Positive_review'],
#  ...]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_array_g2 = te.fit(transactions_g2).transform(transactions_g2)

df_trans_g2 = pd.DataFrame(te_array_g2, columns=te.columns_)

# %%
from mlxtend.frequent_patterns import apriori, association_rules

freq_items_g2 = apriori(
    df_trans_g2,
    min_support=0.03,   # thấp hơn nhóm 1 vì nhiều item hơn
    use_colnames=True
)

# %%
rules_g2 = association_rules(
    freq_items_g2,
    metric='confidence',
    min_threshold=0.6
)

# %%
rules_g2 = rules_g2[
    rules_g2['consequents'].astype(str).str.contains('review')
]

# %%
rules_g2 = rules_g2[
    rules_g2['antecedents'].astype(str).str.contains(
        'Late_delivery|On_time_delivery|Speed_'
    )
]

# %%
rules_g2 = rules_g2.sort_values(
    by=['lift', 'confidence'],
    ascending=False
)

rules_g2.head(10)
# Out:
#                           antecedents                          consequents  \
# 199                   (Late_delivery)        (Speed_Slow, Negative_review)
# 198       (Late_delivery, Speed_Slow)                    (Negative_review)
# 39                    (Late_delivery)                    (Negative_review)
# 356         (Expensive, Speed_Normal)  (On_time_delivery, Positive_review)
# 232                      (Speed_Fast)  (On_time_delivery, Positive_review)
# 320               (Cheap, Speed_Fast)  (On_time_delivery, Positive_review)
# 390               (Speed_Fast, Light)  (On_time_delivery, Positive_review)
# 401              (Speed_Fast, Medium)  (On_time_delivery, Positive_review)
# 425  (Expensive, Heavy, Speed_Normal)  (On_time_delivery, Positive_review)
# 374             (Heavy, Speed_Normal)  (On_time_delivery, Positive_review)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 199            0.077815            0.174310  0.050316    0.646612  3.709547
# 198            0.074278            0.231953  0.050316    0.677396  2.920399
# 39             0.077815            0.231953  0.051161    0.657477  2.834524
# 356            0.076797            0.741394  0.065188    0.848840  1.144925
# 232            0.090169            0.741394  0.076487    0.848271  1.144157
# 320            0.040344            0.741394  0.034153    0.846553  1.141840
# 390            0.042262            0.741394  0.035680    0.844268  1.138758
# 401            0.043007            0.741394  0.036253    0.842951  1.136981
# 425            0.040635            0.741394  0.034108    0.839374  1.132157
# 374            0.078424            0.741394  0.064797    0.826243  1.114446
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 199               1.0  0.036752    2.336497       0.792059  0.249324
# 198               1.0  0.033087    2.380771       0.710344  0.196611
# 39                1.0  0.033112    2.242320       0.701819  0.197835
# 356               1.0  0.008252    1.710812       0.137110  0.086571
# 232               1.0  0.009637    1.704397       0.138481  0.101298
# 320               1.0  0.004242    1.685309       0.129442  0.045684
# 390               1.0  0.004348    1.660582       0.127227  0.047702
# 401               1.0  0.004368    1.646658       0.125892  0.048457
# 425               1.0  0.003981    1.609987       0.121674  0.045603
# 374               1.0  0.006654    1.488324       0.111432  0.085822
#
#      certainty  kulczynski
# 199   0.572009    0.467635
# 198   0.579968    0.447159
# 39    0.554033    0.439022
# 356   0.415482    0.468383
# 232   0.413282    0.475719
# 320   0.406637    0.446309
# 390   0.397801    0.446197
# 401   0.392709    0.445925
# 425   0.378877    0.442689
# 374   0.328103    0.456821

# %% [markdown]
# Mặc dù luật tiêu cực chủ yếu xoay quanh giao hàng, việc các luật tích cực phía dưới đều gắn với đặc điểm sản phẩm cho thấy:
#
# Khi điều kiện giao hàng không thuận lợi, đặc điểm sản phẩm không đủ để “cứu” trải nghiệm, và đánh giá tiêu cực vẫn chiếm ưu thế.
#
# Điều này gián tiếp khẳng định vai trò điều chỉnh (chứ không thay thế) của sản phẩm.
#
# Khi giao hàng thuận lợi, các đặc điểm sản phẩm:
#
# nhẹ / nặng
#
# rẻ / trung bình / đắt
#
# đều duy trì được mức độ hài lòng cao.
#
# Tác động của giao hàng mạnh hơn sản phẩm rất nhiều
# Sản phẩm không tạo ra đột biến, mà:
#
# giúp củng cố trải nghiệm tích cực khi giao hàng đã tốt
#
# đặc điểm sản phẩm không phải là yếu tố quyết định chính gây ra sự không hài lòng của khách hàng. Tuy nhiên, khi kết hợp với điều kiện giao hàng thuận lợi, các đặc điểm sản phẩm như trọng lượng và mức giá giúp duy trì mức độ hài lòng cao. Ngược lại, trong các trường hợp giao hàng trễ hoặc giao chậm, tác động tiêu cực của giao hàng chi phối mạnh mẽ trải nghiệm khách hàng, bất kể đặc điểm sản phẩm
#
# Mức độ hài lòng của khách hàng trên nền tảng Olist chịu ảnh hưởng chủ yếu từ yếu tố giao hàng. Đặc điểm sản phẩm đóng vai trò điều chỉnh, làm rõ sự khác biệt trong trải nghiệm khi điều kiện giao hàng thuận lợi, nhưng không đủ để bù đắp cho các vấn đề giao hàng.

# %% [markdown]
# ## 1.3. Khách hàng có sẵn sàng chấp nhận chi phí cao nếu trải nghiệm giao hàng tốt không?

# %%
transactions_g3 = df[[
    'price_level',        # Cheap / Medium / Expensive
    'freight_level',      # Low / Medium / High
    'delivery_speed',     # Fast / Normal / Slow
    'late_item',          # On_time_delivery / Late_delivery
    'review_item'         # Positive_review / Negative_review
]].astype(str).values.tolist()

# %%
transactions_g3
# Out:
# [['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Negative_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'Late_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'Late_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Fast', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_nan', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Negative_review'],
#  ['Expensive', 'High', 'Speed_Fast', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
# ...
#   'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_nan', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'Late_delivery', 'Positive_review'],
#  ['Expensive',
#   'Medium',
#   'Speed_Normal',
#   'On_time_delivery',
#   'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Low', 'Speed_Fast', 'On_time_delivery', 'Negative_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Low', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Fast', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Medium', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Low', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Expensive', 'Medium', 'Speed_Slow', 'Late_delivery', 'Negative_review'],
#  ['Cheap', 'High', 'Speed_Slow', 'On_time_delivery', 'Positive_review'],
#  ['Cheap', 'Medium', 'Speed_Slow', 'On_time_delivery', 'Negative_review'],
#  ['Cheap', 'Medium', 'Speed_Normal', 'On_time_delivery', 'Positive_review'],
#  ...]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_array = te.fit(transactions_g3).transform(transactions_g3)

df_trans_g3 = pd.DataFrame(te_array, columns=te.columns_)

# %%
from mlxtend.frequent_patterns import apriori, association_rules

frequent_itemsets_g3 = apriori(
    df_trans_g3,
    min_support=0.03,
    use_colnames=True
)

# %%
rules_g3 = association_rules(
    frequent_itemsets_g3,
    metric='confidence',
    min_threshold=0.7
)

# %%
rules_g3_focus = rules_g3[
    rules_g3['antecedents'].astype(str).str.contains(
        'Cheap|Medium|Expensive|Low|High', regex=True
    ) &
    rules_g3['consequents'].astype(str).str.contains(
        'Positive_review|Negative_review|On_time_delivery|Late_delivery',
        regex=True
    )
]

# %%
rules_g3_focus = rules_g3_focus.sort_values(
    by=['lift', 'confidence'],
    ascending=False
)

rules_g3_focus[[
    'antecedents',
    'consequents',
    'support',
    'confidence',
    'lift'
]].head(15)
# Out:
#                                antecedents  \
# 219                    (Cheap, Speed_Fast)
# 216  (Cheap, On_time_delivery, Speed_Fast)
# 128                    (Cheap, Speed_Fast)
# 217   (Cheap, Positive_review, Speed_Fast)
# 123                    (Cheap, Speed_Fast)
# 188                (Positive_review, High)
# 240        (Medium, Positive_review, High)
# 233     (Expensive, Positive_review, High)
# 117                          (Cheap, High)
# 228       (Cheap, Positive_review, Medium)
# 72                                  (High)
# 177                         (High, Medium)
# 200                      (Speed_Fast, Low)
# 218               (Cheap, Speed_Fast, Low)
# 168              (Expensive, Speed_Normal)
#
#                                   consequents   support  confidence      lift
# 219  (On_time_delivery, Positive_review, Low)  0.031644    0.784362  3.083656
# 216                    (Positive_review, Low)  0.031644    0.788270  2.993118
# 128                    (Positive_review, Low)  0.031799    0.788193  2.992826
# 217                   (On_time_delivery, Low)  0.031644    0.922119  2.936904
# 123                   (On_time_delivery, Low)  0.036898    0.914601  2.912959
# 188            (On_time_delivery, Speed_Slow)  0.184255    0.738048  1.287426
# 240            (On_time_delivery, Speed_Slow)  0.053579    0.737857  1.287093
# 233            (On_time_delivery, Speed_Slow)  0.103904    0.730118  1.273594
# 117            (On_time_delivery, Speed_Slow)  0.034735    0.726012  1.266431
# 228            (On_time_delivery, Speed_Slow)  0.067951    0.709203  1.237110
# 72             (On_time_delivery, Speed_Slow)  0.234362    0.703726  1.227556
# 177            (On_time_delivery, Speed_Slow)  0.068824    0.700889  1.222607
# 200       (On_time_delivery, Positive_review)  0.061752    0.853714  1.151499
# 218       (On_time_delivery, Positive_review)  0.031644    0.853186  1.150787
# 168       (On_time_delivery, Positive_review)  0.065188    0.848840  1.144925

# %% [markdown]
# Chi phí thấp không tự tạo ra hài lòng, nhưng khi kết hợp với giao hàng nhanh, nó tạo thành một tổ hợp trải nghiệm rất tích cực.
#
# Khách hàng chấp nhận giao chậm nếu không trễ, nhưng phí cao + giao chậm làm trải nghiệm kém hấp dẫn hơn so với tổ hợp chi phí thấp – giao nhanh.
#
# Giao hàng vẫn là yếu tố nền
#
# Chi phí chỉ điều chỉnh mức độ hài lòng, không quyết định tuyệt đối
#
# Mức độ hài lòng của khách hàng trên Olist không phụ thuộc riêng lẻ vào chi phí hay giao hàng, mà hình thành từ các tổ hợp yếu tố.

# %% [markdown]
# ## 1.4. KHU VỰC KHÁCH HÀNG TRONG MỐI LIÊN HỆ VỚI GIAO HÀNG & HÀI LÒNG

# %%
transactions_g4 = df[
    [
        'state_item',
        'late_item',
        'delivery_speed',
        'review_item'
    ]
].values.tolist()

# %%
transactions_g4[:5]
# Out:
# [['State_SP', 'On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['State_BA', 'On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['State_GO', 'On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['State_RN', 'On_time_delivery', 'Speed_Slow', 'Positive_review'],
#  ['State_SP', 'On_time_delivery', 'Speed_Fast', 'Positive_review']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_array = te.fit(transactions_g4).transform(transactions_g4)

df_trans_g4 = pd.DataFrame(te_array, columns=te.columns_)

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets_g4 = apriori(
    df_trans_g4,
    min_support=0.01,
    use_colnames=True
)

# %%
from mlxtend.frequent_patterns import association_rules

rules_g4 = association_rules(
    frequent_itemsets_g4,
    metric='confidence',
    min_threshold=0.6
)

# %%
rules_g4_filtered = rules_g4[
    rules_g4['antecedents'].apply(lambda x: any('State_' in i for i in x)) &
    rules_g4['consequents'].apply(lambda x: any('review' in i.lower() for i in x))
]

# %%
rules_g4_filtered = rules_g4_filtered.sort_values(
    by=['lift', 'confidence'],
    ascending=False
)

rules_g4_filtered.head(10)
# Out:
#                                antecedents  \
# 191              (State_RJ, Late_delivery)
# 189  (State_RJ, Late_delivery, Speed_Slow)
# 53               (State_RJ, Late_delivery)
# 192  (Late_delivery, State_SP, Speed_Slow)
# 261           (On_time_delivery, State_PE)
# 230           (On_time_delivery, State_BA)
# 264                             (State_PE)
# 249           (On_time_delivery, State_GO)
# 178                             (State_PE)
# 242           (On_time_delivery, State_ES)
#
#                                          consequents  antecedent support  \
# 191                    (Negative_review, Speed_Slow)            0.016363
# 189                                (Negative_review)            0.016081
# 53                                 (Negative_review)            0.016363
# 192                                (Negative_review)            0.021254
# 261                    (Positive_review, Speed_Slow)            0.014236
# 230                    (Positive_review, Speed_Slow)            0.028871
# 264  (On_time_delivery, Positive_review, Speed_Slow)            0.015817
# 249                    (Positive_review, Speed_Slow)            0.018972
# 178                    (Positive_review, Speed_Slow)            0.015817
# 242                    (Positive_review, Speed_Slow)            0.017654
#
#      consequent support   support  confidence      lift  representativity  \
# 191            0.174310  0.012527    0.765556  4.391913               1.0
# 189            0.231953  0.012527    0.778971  3.358313               1.0
# 53             0.231953  0.012609    0.770556  3.322032               1.0
# 192            0.231953  0.012981    0.610778  2.633198               1.0
# 261            0.473242  0.010572    0.742656  1.569295               1.0
# 230            0.473242  0.020572    0.712531  1.505638               1.0
# 264            0.449280  0.010572    0.668391  1.487695               1.0
# 249            0.473242  0.013281    0.700048  1.479260               1.0
# 178            0.473242  0.011018    0.696552  1.471872               1.0
# 242            0.473242  0.012145    0.687951  1.453697               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 191  0.009674    3.521899       0.785156  0.070317   0.716062    0.418710
# 189  0.008797    3.474872       0.713709  0.053190   0.712220    0.416488
# 53   0.008813    3.347420       0.710607  0.053492   0.701262    0.412457
# 192  0.008051    1.973290       0.633702  0.054038   0.493232    0.333372
# 261  0.003835    2.046905       0.368010  0.022168   0.511458    0.382498
# 230  0.006909    1.832402       0.345814  0.042721   0.454268    0.378001
# 264  0.003466    1.660751       0.333088  0.023260   0.397863    0.345961
# 249  0.004303    1.756140       0.330252  0.027731   0.430569    0.364056
# 178  0.003532    1.735907       0.325745  0.023048   0.423932    0.359917
# 242  0.003790    1.688059       0.317707  0.025368   0.407604    0.356807

# %% [markdown]
# Ở các bang lớn như RJ, SP, khi giao chậm + trễ, xác suất đánh giá tiêu cực tăng gấp 3–4 lần
#
# Lift rất cao ⇒ mối liên hệ mạnh, không phải ngẫu nhiên
#
# Cùng là giao trễ, nhưng ở một số khu vực, tác động tiêu cực mạnh hơn rõ rệt.
#
# Giao chậm nhưng đúng hạn vẫn thường đi kèm Positive_review
#
# Điều này xuất hiện ổn định ở nhiều bang
#
# Khu vực khách hàng không phải nguyên nhân trực tiếp, mà là yếu tố điều kiện làm thay đổi mức độ tác động của giao hàng đến sự hài lòng.
#
# Khu vực khách hàng không ảnh hưởng trực tiếp đến mức độ hài lòng, nhưng đóng vai trò như một yếu tố bối cảnh quan trọng. Khi kết hợp với trạng thái và tốc độ giao hàng, khu vực địa lý có thể làm gia tăng hoặc làm giảm tác động của giao hàng đến đánh giá của khách hàng.

# %% [markdown]
# ## 1.5. Tổng kết lại

# %%
transactions_g5 = df[
    [
        # Delivery
        'late_item',
        'delivery_speed',

        # Product
        'category_item',
        'weight_level',

        # Cost
        'price_level',
        'freight_level',

        # Region
        'state_item',

        # Output
        'review_item'
    ]
].values.tolist()

# %%
transactions_g5[:5]
# Out:
# [['On_time_delivery',
#   'Speed_Slow',
#   'Category_housewares',
#   'Medium',
#   'Cheap',
#   'Low',
#   'State_SP',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Category_perfumery',
#   'Light',
#   'Expensive',
#   'High',
#   'State_BA',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Category_auto',
#   'Medium',
#   'Expensive',
#   'High',
#   'State_GO',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Slow',
#   'Category_pet_shop',
#   'Medium',
#   'Cheap',
#   'High',
#   'State_RN',
#   'Positive_review'],
#  ['On_time_delivery',
#   'Speed_Fast',
#   'Category_stationery',
#   'Light',
#   'Cheap',
#   'Low',
#   'State_SP',
#   'Positive_review']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_array = te.fit(transactions_g5).transform(transactions_g5)

df_trans_g5 = pd.DataFrame(te_array, columns=te.columns_)

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets_g5 = apriori(
    df_trans_g5,
    min_support=0.03,
    use_colnames=True
)

# %%
from mlxtend.frequent_patterns import association_rules

rules_g5 = association_rules(
    frequent_itemsets_g5,
    metric='confidence',
    min_threshold=0.6
)

# %%
def count_groups(items):
    groups = {
        'delivery': ['Late_delivery', 'On_time_delivery', 'Speed_'],
        'product': ['Category_', 'Light', 'Medium', 'Heavy'],
        'cost': ['Cheap', 'Medium', 'Expensive', 'Low', 'High'],
        'region': ['State_']
    }

    used = set()
    for item in items:
        for g, keys in groups.items():
            if any(k in item for k in keys):
                used.add(g)
    return len(used)

rules_g5_filtered = rules_g5[
    rules_g5['consequents'].apply(lambda x: any('review' in i.lower() for i in x))
]

rules_g5_filtered['num_groups'] = rules_g5_filtered['antecedents'].apply(count_groups)

rules_g5_final = rules_g5_filtered[
    (rules_g5_filtered['num_groups'] >= 3) &
    (rules_g5_filtered['lift'] > 1.2) &
    (rules_g5_filtered['support'] > 0.01)
]
# Out:
# C:\Users\biena\AppData\Local\Temp\ipykernel_19644\2894498882.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rules_g5_filtered['num_groups'] = rules_g5_filtered['antecedents'].apply(count_groups)

# %%
rules_g5_final = rules_g5_final.sort_values(
    by=['lift', 'confidence'],
    ascending=False
)

rules_g5_final.head(10)
# Out:
#                                             antecedents  \
# 1001                            (Late_delivery, Medium)
# 998                 (Speed_Slow, Late_delivery, Medium)
# 359                             (Late_delivery, Medium)
# 1767         (Cheap, On_time_delivery, State_SP, Light)
# 1831                    (Speed_Normal, State_SP, Light)
# 1808                    (Cheap, Speed_Normal, State_SP)
# 1774                           (Cheap, State_SP, Light)
# 1623                    (Speed_Normal, State_SP, Light)
# 1826  (On_time_delivery, Speed_Normal, State_SP, Light)
# 1322                           (Cheap, State_SP, Light)
#
#                                    consequents  antecedent support  \
# 1001             (Negative_review, Speed_Slow)            0.051379
# 998                          (Negative_review)            0.049461
# 359                          (Negative_review)            0.051379
# 1767                    (Positive_review, Low)            0.094278
# 1831  (On_time_delivery, Positive_review, Low)            0.064006
# 1808  (On_time_delivery, Positive_review, Low)            0.064806
# 1774  (On_time_delivery, Positive_review, Low)            0.099259
# 1623                    (Positive_review, Low)            0.064006
# 1826                    (Positive_review, Low)            0.062988
# 1322                    (Positive_review, Low)            0.099259
#
#       consequent support   support  confidence      lift  representativity  \
# 1001            0.174310  0.033644    0.654812  3.756592               1.0
# 998             0.231953  0.033644    0.680206  2.932515               1.0
# 359             0.231953  0.034080    0.663305  2.859652               1.0
# 1767            0.263361  0.066915    0.709768  2.695039               1.0
# 1831            0.254361  0.043807    0.684420  2.690740               1.0
# 1808            0.254361  0.043771    0.675410  2.655320               1.0
# 1774            0.254361  0.066915    0.674146  2.650349               1.0
# 1623            0.263361  0.044562    0.696208  2.643552               1.0
# 1826            0.263361  0.043807    0.695483  2.640799               1.0
# 1322            0.263361  0.068997    0.695119  2.639416               1.0
#
#       leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 1001  0.024688    2.392003       0.773546  0.175187   0.581940    0.423912
# 998   0.022171    2.401692       0.693287  0.135787   0.583627    0.412626
# 359   0.022163    2.281136       0.685529  0.136730   0.561622    0.405116
# 1767  0.042086    2.538102       0.694416  0.230168   0.606005    0.481925
# 1831  0.027526    2.362756       0.671324  0.159554   0.576765    0.428322
# 1808  0.027287    2.297173       0.666597  0.158937   0.564682    0.423746
# 1774  0.041667    2.288260       0.691310  0.233394   0.562987    0.468609
# 1623  0.027705    2.424814       0.664236  0.157570   0.587597    0.432706
# 1826  0.027219    2.419039       0.663094  0.155046   0.586613    0.430911
# 1322  0.042856    2.416150       0.689575  0.234985   0.586118    0.478552
#
#       num_groups
# 1001           3
# 998            3
# 359            3
# 1767           4
# 1831           3
# 1808           3
# 1774           3
# 1623           3
# 1826           3
# 1322           3

# %% [markdown]
# Late_delivery là lõi tiêu cực
#
# Khi kết hợp thêm:
#
# Sản phẩm nặng
#
# Chi phí cao / trung bình
# → Xác suất đánh giá tiêu cực tăng gấp ~4 lần
#
# Kết luận quan trọng:
#
# Khi giao hàng trễ xảy ra, các yếu tố sản phẩm và chi phí khuếch đại mạnh tác động tiêu cực lên sự hài lòng.
#
# Giao nhanh + đúng hạn là nền
#
# Giá rẻ + phí thấp + hàng nhẹ
#
# Khu vực SP (gần trung tâm logistics)
#
# → Tạo thành tổ hợp trải nghiệm gần như lý tưởng
#
# Ý nghĩa:
#
# Không yếu tố nào trong số này đủ mạnh một mình, nhưng khi kết hợp lại → mức độ hài lòng tăng vọt (lift > 3).
#
# State_SP chỉ xuất hiện trong các luật tích cực
#
# Không xuất hiện đơn lẻ, mà luôn đi kèm:
#
# Speed_Fast
#
# On_time_delivery
#
# Low freight
#
# Khu vực không tạo hài lòng, nhưng tạo điều kiện để giao hàng hiệu quả, từ đó hình thành trải nghiệm tích cực.
#
# Sự hài lòng không đến từ một yếu tố đơn lẻ
#
# Các tổ hợp tích cực (giao nhanh, đúng hạn, chi phí thấp, hàng nhẹ, khu vực thuận lợi) làm xác suất đánh giá tích cực tăng gấp nhiều lần
#
# Kết quả khai phá luật kết hợp cho thấy mức độ hài lòng của khách hàng trên nền tảng Olist được hình thành từ sự tương tác của nhiều yếu tố liên quan đến giao hàng, sản phẩm, chi phí và khu vực địa lý. Không có yếu tố nào tác động độc lập, mà chính các tổ hợp điều kiện mới quyết định trải nghiệm và đánh giá của khách hàng.

# %% [markdown]
# # 2. Tối ưu hóa doanh thu

# %% [markdown]
# ## 2.1. Nhóm khách hàng
#
# Khách hàng trung thành đóng góp bao nhiêu % tổng doanh thu?
#
# Giá trị trung bình mỗi đơn hàng (Average Order Value) của khách hàng trung thành và khách hàng mới khác nhau như thế nào?
#
# Những nhóm khách hàng tiềm năng nào chưa được khai thác, có khả năng mang lại doanh thu cao?

# %%
data = pd.read_csv("master_data.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110012 entries, 0 to 110011
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       110012 non-null  object
#  1   customer_id                    110012 non-null  object
#  2   order_status                   110012 non-null  object
#  3   order_purchase_timestamp       110012 non-null  object
#  4   order_approved_at              109997 non-null  object
#  5   order_delivered_carrier_date   110011 non-null  object
#  6   order_delivered_customer_date  110012 non-null  object
#  7   order_estimated_delivery_date  110012 non-null  object
#  8   order_item_id                  110012 non-null  float64
#  9   product_id                     110012 non-null  object
#  10  seller_id                      110012 non-null  object
#  11  shipping_limit_date            110012 non-null  object
#  12  price                          110012 non-null  float64
#  13  freight_value                  110012 non-null  float64
#  14  product_category_name          108457 non-null  object
#  15  product_name_lenght            108479 non-null  float64
#  16  product_description_lenght     108479 non-null  float64
#  17  product_photos_qty             108479 non-null  float64
#  18  product_weight_g               109994 non-null  float64
#  19  product_length_cm              109994 non-null  float64
#  20  product_height_cm              109994 non-null  float64
#  21  product_width_cm               109994 non-null  float64
#  22  customer_unique_id             110012 non-null  object
#  23  customer_zip_code_prefix       110012 non-null  int64
#  24  customer_city                  110012 non-null  object
#  25  customer_state                 110012 non-null  object
#  26  review_id                      110012 non-null  object
#  27  review_score                   110012 non-null  float64
#  28  review_comment_title           13126 non-null   object
#  29  review_comment_message         46137 non-null   object
#  30  review_creation_date           110012 non-null  object
#  31  review_answer_timestamp        110012 non-null  object
#  32  delivery_days                  110012 non-null  int64
#  33  is_late                        110012 non-null  int64
#  34  review_binary                  110012 non-null  int64
# dtypes: float64(11), int64(4), object(20)
# memory usage: 29.4+ MB

# %%
# Chuyển cột ngày sang datetime
data['order_purchase_timestamp'] = pd.to_datetime(data['order_purchase_timestamp'])

# Tạo cột doanh thu mỗi item
data['order_value'] = data['price'] + data['freight_value']

# Lấy ngày phân tích (ngày gần nhất trong dataset)
snapshot_date = data['order_purchase_timestamp'].max() + pd.Timedelta(days=1)

# Tính RFM
rfm = data.groupby('customer_unique_id').agg({
    'order_purchase_timestamp': lambda x: (snapshot_date - x.max()).days,  # Recency
    'order_id': 'nunique',  # Frequency
    'order_value': 'sum'    # Monetary
}).reset_index()

rfm.rename(columns={
    'order_purchase_timestamp': 'Recency',
    'order_id': 'Frequency',
    'order_value': 'Monetary'
}, inplace=True)

rfm
# Out:
#                      customer_unique_id  Recency  Frequency  Monetary
# 0      0000366f3b9a7992bf8c76cfdf3221e2      112          1    141.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      115          1     27.19
# 2      0000f46a3911fa3c0805444483337064      537          1     86.22
# 3      0000f6ccb0745a6a4b88665a16c9f078      321          1     43.62
# 4      0004aac84e0df4da2b147fca70cf8255      288          1    196.89
# ...                                 ...      ...        ...       ...
# 92748  fffcf5a5ff07b0908bd4e2dbc735a684      447          1   2067.42
# 92749  fffea47cd6d3cc0a88bd621562a9d061      262          1     84.58
# 92750  ffff371b4d645b6ecea244b27531430a      568          1    112.46
# 92751  ffff5962728ec6157033ef9805bacc48      119          1    133.69
# 92752  ffffd2657e2aad2907e67c3e9daecbeb      484          1     71.56
#
# [92753 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm[['Recency','Frequency','Monetary']])

# %%
import matplotlib.pyplot as plt
inertia = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(rfm_scaled)
    inertia.append(kmeans.inertia_)

# Vẽ biểu đồ Elbow
plt.figure(figsize=(8,5))
plt.plot(K_range, inertia, marker='o')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia (Sum of Squared Distances)')
plt.xticks(K_range)
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4, random_state=42)
rfm['Cluster'] = kmeans.fit_predict(rfm_scaled)

# Thống kê mỗi cụm
cluster_summary = rfm.groupby('Cluster').agg({
    'Recency':'mean',
    'Frequency':'mean',
    'Monetary':['mean','count']
}).round(2)

print(cluster_summary)
# Out:
#         Recency Frequency Monetary
#            mean      mean     mean  count
# Cluster
# 0        239.17      1.01  1160.16   2403
# 1        387.39      1.00   133.43  37274
# 2        127.97      1.00   134.26  50345
# 3        220.47      2.11   307.48   2731

# %%
# Tạo dictionary mapping: customer_unique_id -> Cluster
cluster_map = rfm.set_index('customer_unique_id')['Cluster'].to_dict()

# Map cluster vào data
data['Customer_Cluster'] = data['customer_unique_id'].map(cluster_map)

# Kiểm tra kết quả
print(data[['customer_unique_id','order_id','Customer_Cluster']].head(10))
# Out:
#                  customer_unique_id                          order_id  \
# 0  7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 1  af07308b275d755c9edb36a90c618231  53cdb2fc8bc7dce0b6741e2150273451
# 2  3a653a41f6f9fc3d2a113cf8398680e8  47770eb9100c2d0c44946d9cf07ec65d
# 3  7c142cf63193a1473d2e66489a9ae977  949d5b44dbf5de918fe9c16f97b45f8a
# 4  72632f0f9dd73dfee390c9b22eb56dd6  ad21c59c0840e6cb83a9ceb5573f8159
# 5  80bb27c7c16e8f973207a5086ab329e2  a4591c265e18cb1dcee52889e2d8acc3
# 6  932afa1e708222e5821dac9cd5db4cae  6514b8ad8028c9f2cc2374ded245783f
# 7  39382392765b6dc74812866ee5ee92a7  76c6e866289321a7c93b82b54852dc33
# 8  299905e3934e9e181bfb2e164dd4b4f8  e69bfb5eb88e0ed6a785585b27e16dbf
# 9  f2a85dec752b8517b5e58a06ff3cd937  e6ce16cb79ec1d90b1da9085a6118aeb
#
#    Customer_Cluster
# 0                 3
# 1                 2
# 2                 2
# 3                 1
# 4                 2
# 5                 1
# 6                 1
# 7                 1
# 8                 1
# 9                 1

# %%
cluster_labels = {
    0: 'VIP',
    1: 'At Risk',
    2: 'New',
    3: 'Loyal'
}

# Map nhãn vào dataframe rfm
rfm['Customer_Label'] = rfm['Cluster'].map(cluster_labels)

# Map nhãn vào data gốc dựa trên customer_unique_id
label_map = rfm.set_index('customer_unique_id')['Customer_Label'].to_dict()
data['Customer_Label'] = data['customer_unique_id'].map(label_map)

# Kiểm tra kết quả
print(data[['customer_unique_id','order_id','Customer_Cluster','Customer_Label']].head(10))
# Out:
#                  customer_unique_id                          order_id  \
# 0  7c396fd4830fd04220f754e42b4e5bff  e481f51cbdc54678b7cc49136f2d6af7
# 1  af07308b275d755c9edb36a90c618231  53cdb2fc8bc7dce0b6741e2150273451
# 2  3a653a41f6f9fc3d2a113cf8398680e8  47770eb9100c2d0c44946d9cf07ec65d
# 3  7c142cf63193a1473d2e66489a9ae977  949d5b44dbf5de918fe9c16f97b45f8a
# 4  72632f0f9dd73dfee390c9b22eb56dd6  ad21c59c0840e6cb83a9ceb5573f8159
# 5  80bb27c7c16e8f973207a5086ab329e2  a4591c265e18cb1dcee52889e2d8acc3
# 6  932afa1e708222e5821dac9cd5db4cae  6514b8ad8028c9f2cc2374ded245783f
# 7  39382392765b6dc74812866ee5ee92a7  76c6e866289321a7c93b82b54852dc33
# 8  299905e3934e9e181bfb2e164dd4b4f8  e69bfb5eb88e0ed6a785585b27e16dbf
# 9  f2a85dec752b8517b5e58a06ff3cd937  e6ce16cb79ec1d90b1da9085a6118aeb
#
#    Customer_Cluster Customer_Label
# 0                 3          Loyal
# 1                 2            New
# 2                 2            New
# 3                 1        At Risk
# 4                 2            New
# 5                 1        At Risk
# 6                 1        At Risk
# 7                 1        At Risk
# 8                 1        At Risk
# 9                 1        At Risk

# %%
# Tổng doanh thu theo nhãn khách
data['order_value'] = data['price'] + data['freight_value']
revenue_by_label = data.groupby('Customer_Label')['order_value'].sum().sort_values(ascending=False)
print(revenue_by_label)

# Số đơn hàng trung bình theo nhãn khách
avg_orders_by_label = data.groupby('Customer_Label')['order_id'].nunique()
print(avg_orders_by_label)
# Out:
# Customer_Label
# New        6759495.27
# At Risk    4973520.91
# VIP        2787868.08
# Loyal       839730.51
# Name: order_value, dtype: float64
# Customer_Label
# At Risk    37274
# Loyal       5773
# New        50345
# VIP         2438
# Name: order_id, dtype: int64

# %% [markdown]
# New (6.75 triệu doanh thu, 50k đơn)
#
# Khách mới, chi tiêu trung bình thấp (~134/order)
#
# Chiến lược: upsell, cross-sell, khuyến khích mua lần tiếp theo
#
# At Risk (4.97 triệu doanh thu, 37k đơn)
#
# Khách lâu không mua, chi tiêu thấp
#
# Chiến lược: tái kích hoạt, gửi voucher hoặc email nhắc mua
#
# VIP (2.78 triệu doanh thu, 2.4k đơn)
#
# Khách chi tiêu cao từng đơn (~1,145/order) nhưng mua ít
#
# Chiến lược: kích thích mua lại, chăm sóc cá nhân, ưu đãi đặc biệt
#
# Loyal (0.84 triệu doanh thu, 5.7k đơn)
#
# Khách trung thành, mua nhiều lần
#
# Chiến lược: giữ chân, upsell, tạo chương trình loyalty
#
# Khách mới + At Risk đóng góp phần lớn doanh thu tổng, nhưng chi tiêu mỗi đơn thấp → doanh nghiệp nên tập trung tối ưu AOV và tần suất mua.
#
# VIP và Loyal chi tiêu cao, dù số lượng khách ít, nên tập trung giữ chân và tăng mua lại → trực tiếp tối ưu hóa doanh thu.

# %%
import matplotlib.pyplot as plt

# Tính AOV trung bình theo nhãn khách
aov_by_label = data.groupby('Customer_Label')['order_value'].mean()

# Tổng doanh thu theo nhãn khách
revenue_by_label = data.groupby('Customer_Label')['order_value'].sum()

# Số đơn hàng theo nhãn khách
orders_by_label = data.groupby('Customer_Label')['order_id'].nunique()

# Sắp xếp nhãn theo thứ tự chiến lược
labels_order = ['New','At Risk','VIP','Loyal']

# Vẽ biểu đồ
plt.figure(figsize=(18,5))

# 1. Tổng doanh thu
plt.subplot(1,3,1)
plt.bar(revenue_by_label[labels_order].index, revenue_by_label[labels_order].values, color='skyblue')
plt.title('Tổng Doanh Thu theo Nhóm Khách Hàng')
plt.ylabel('Tổng doanh thu')
plt.xticks(rotation=15)

# 2. Số đơn hàng
plt.subplot(1,3,2)
plt.bar(orders_by_label[labels_order].index, orders_by_label[labels_order].values, color='orange')
plt.title('Số Đơn Hàng theo Nhóm Khách Hàng')
plt.ylabel('Số đơn hàng')
plt.xticks(rotation=15)

# 3. AOV trung bình
plt.subplot(1,3,3)
plt.bar(aov_by_label[labels_order].index, aov_by_label[labels_order].values, color='green')
plt.title('AOV Trung Bình theo Nhóm Khách Hàng')
plt.ylabel('Giá trị trung bình mỗi đơn (AOV)')
plt.xticks(rotation=15)

plt.tight_layout()
plt.show()

# %%
# Xuất ra CSV
data.to_csv('master_data_with_customer_label.csv', index=False)

# Xuất ra pickle
data.to_pickle('master_data_with_customer_label.pkl')

print("Đã xuất file CSV và PKL thành công!")
# Out:
# Đã xuất file CSV và PKL thành công!

# %%
# AOV = tổng doanh thu / số đơn hàng
aov_loyal = data[data['Customer_Label']=='Loyal']['order_value'].sum() / \
            data[data['Customer_Label']=='Loyal']['order_id'].nunique()

aov_new = data[data['Customer_Label']=='New']['order_value'].sum() / \
          data[data['Customer_Label']=='New']['order_id'].nunique()

print(f"AOV khách trung thành: {aov_loyal:.2f}")
print(f"AOV khách mới: {aov_new:.2f}")
# Out:
# AOV khách trung thành: 145.46
# AOV khách mới: 134.26

# %% [markdown]
# Doanh thu từ khách trung thành (Loyal): ~839,730
#
# Tỷ lệ so với tổng doanh thu: ~5.9% (so với tổng doanh thu ~14,500,000)
#
# Nhận xét: dù số khách trung thành ít (~5,773 khách), họ vẫn chiếm một phần quan trọng và đáng được chăm sóc để giữ chân lâu dài.
#
# Khách trung thành có AOV cao hơn khách mới, dù số lượng đơn ít hơn nhiều → chi tiêu trung bình mỗi đơn lớn hơn.
#
# Điều này chứng tỏ giá trị trung bình đơn hàng của khách trung thành lớn, nên việc giữ chân họ là quan trọng.
#
# Nhóm VIP: số khách ít (~ 2,438 khách), nhưng AOV rất cao (~ 1,145 / đơn) → tiềm năng doanh thu lớn nếu kích thích mua lại nhiều lần.
#
# Nhóm New: số khách nhiều (~ 50,345 khách), chi tiêu mỗi đơn thấp (~ 134), nhưng tổng doanh thu cao → nếu upsell/cross-sell đúng cách → có thể tăng doanh thu nhanh chóng.
#
# Nhận xét:
#
# VIP là nhóm chi tiêu cao nhưng mua ít → tập trung chiến dịch khuyến mãi cá nhân, upsell, giữ chân VIP.
#
# New là nhóm khách số lượng lớn, cần kích thích mua lần 2, chương trình chăm sóc, ưu đãi lần đầu → khai thác tiềm năng doanh thu từ số lượng khách đông.

# %% [markdown]
# ## 2.2. Phân tích sản phẩm/danh mục
#
# Sản phẩm nào đóng góp nhiều nhất vào tổng doanh thu theo danh mục, thương hiệu?
#
# Những sản phẩm nào có doanh thu thấp và tần suất mua thấp, cần được xem xét khuyến mãi hoặc loại bỏ khỏi danh mục?
#
# Những tổ hợp sản phẩm nào thường được mua cùng nhau, giúp tăng giá trị giỏ hàng?

# %%
# Doanh thu theo sản phẩm
product_revenue = data.groupby(['product_category_name','product_id']).agg(
    total_revenue=('order_value','sum'),
    num_orders=('order_id','nunique')
).sort_values('total_revenue', ascending=False).reset_index()

# Top 10 sản phẩm doanh thu cao nhất
top_products = product_revenue.head(10)
print(top_products)
# Out:
#    product_category_name                        product_id  total_revenue  \
# 0          health_beauty  bb50f2e236e5eea0100680137654686c       67596.80
# 1  computers_accessories  d1c427060a0f73f6b889a5c7c61f2ac4       58578.57
# 2          health_beauty  6cdd53843498f92890544667809f1595       57555.12
# 3         bed_bath_table  99a4788cb24856965c36a24e339b6058       49412.23
# 4  computers_accessories  3dd2a17168ec895c781a9191c1e95ad7       47698.57
# 5              computers  d6160fb7873f184099d9bc95e30376af       47314.18
# 6        furniture_decor  aca2eb7d00ea1a7b8ebd4e68314663af       43921.63
# 7             cool_stuff  5f504b3a1c75b73d6151be81eb05bdc9       41725.81
# 8          watches_gifts  53b36df67ebb7c41585e8d54d6772e08       39456.05
# 9                   baby  25c38557cf793876c5abdd5931f922db       39286.47
#
#    num_orders
# 0         186
# 1         311
# 2         147
# 3         448
# 4         252
# 5          33
# 6         423
# 7          63
# 8         302
# 9          37

# %% [markdown]
# health_beauty và computers_accessories xuất hiện nhiều lần → là các danh mục chủ lực.
#
# Một số sản phẩm chiếm doanh thu cao dù số đơn ít, ví dụ computers chỉ 33 đơn nhưng doanh thu ~47k → giá trị mỗi đơn cao.

# %%
category_revenue = data.groupby('product_category_name')['order_value'].sum().sort_values(ascending=False)
print(category_revenue)
# Out:
# product_category_name
# health_beauty                1407855.83
# watches_gifts                1257539.51
# bed_bath_table               1229447.33
# sports_leisure               1117494.63
# computers_accessories        1036574.85
#                                 ...
# flowers                         1453.79
# home_comfort_2                  1086.58
# cds_dvds_musicals                954.99
# fashion_childrens_clothes        598.67
# security_and_services            324.51
# Name: order_value, Length: 71, dtype: float64

# %% [markdown]
# health_beauty, watches_gifts, bed_bath_table, sports_leisure, computers_accessories là các danh mục chiếm phần lớn doanh thu.
#
# Danh mục như security_and_services, fashion_childrens_clothes gần như không đóng góp doanh thu → xem xét giảm nhập hoặc chạy khuyến mãi.

# %%
# Xuất CSV
product_revenue.to_csv('all_products_revenue.csv', index=False)
# Xuất PKL
product_revenue.to_pickle('all_products_revenue.pkl')

# Xuất CSV
category_revenue.to_csv('category_revenue.csv', index=False)
# Xuất PKL
category_revenue.to_pickle('category_revenue.pkl')

print("Đã xuất file CSV và PKL thành công cho tất cả sản phẩm và doanh thu theo danh mục!")
# Out:
# Đã xuất file CSV và PKL thành công cho tất cả sản phẩm và doanh thu theo danh mục!

# %%
# Tổng số đơn / tổng doanh thu theo sản phẩm
product_stats = data.groupby('product_id').agg(
    total_revenue=('order_value','sum'),
    num_orders=('order_id','nunique')
).reset_index()

# Lọc sản phẩm doanh thu thấp (ví dụ < 50) và tồn kho nhiều (giả sử tồn kho > threshold)
low_sales_products = product_stats[(product_stats['total_revenue']<50)]
print(low_sales_products.sort_values('total_revenue'))
# Out:
#                              product_id  total_revenue  num_orders
# 8987   46fce52cef5caa7cc225a5531c946c8b           9.59           1
# 26747  d51e0a7f437c0d14f560082ed007fd85           9.95           1
# 6219   310dc32058903b6416c71faff132df9e          10.07           1
# 18386  9334fc63bffa67f685c03b1dc24df180          10.48           1
# 9063   47a83ac845f953b889154d9963dbc1f8          10.88           1
# ...                                 ...            ...         ...
# 3709   1caf2267e1334b93a9220b1a26db262d          49.94           1
# 7266   39849897ee574a067adeb72b6c8e84fa          49.96           1
# 4762   24e19cb0f9da4394876ff32b7a43b99d          49.96           1
# 949    078cec63541a67851b9057468288f722          49.96           1
# 18309  92762f3fd2e9105edc850be0f5b3c51e          49.97           1
#
# [3623 rows x 3 columns]

# %% [markdown]
# Hầu hết sản phẩm:
#
# num_orders = 1
#
# total_revenue ≈ 10–50
#
# Đây là long-tail products:
#
# Rất nhiều
#
# Mỗi cái đóng góp gần như không đáng kể
#
# Nhưng:
#
# Gây phân tán danh mục
#
# Khó quản lý
#
# Không tối ưu chi phí vận hành
#
# Gợi ý chiến lược (để gắn với tối ưu doanh thu):
#
# Gộp khuyến mãi
#
# Gộp mua kèm với sản phẩm bán chạy
#
# Hoặc loại bỏ khỏi danh mục

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Lấy top 15 danh mục phổ biến nhất
top_categories = data['product_category_name'].value_counts().head(15).index

filtered_data = data[data['product_category_name'].isin(top_categories)]

# %%
basket = (
    filtered_data
    .groupby(['order_id','product_category_name'])
    .size()
    .unstack(fill_value=0)
    .astype(bool)
)

# %%
frequent_itemsets = apriori(
    basket,
    min_support=0.01,   # 1% đơn hàng
    use_colnames=True,
    max_len=2           # chỉ xét cặp (pair)
)

# %%
rules = association_rules(
    frequent_itemsets,
    metric="lift",
    min_threshold=1.2
).sort_values('lift', ascending=False)

rules.head(10)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []

# %%
items_per_order = data.groupby('order_id')['product_id'].nunique()
items_per_order.describe()
# Out:
# count    95830.000000
# mean         1.038318
# std          0.227214
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          8.000000
# Name: product_id, dtype: float64

# %% [markdown]
# Phân tích cấu trúc đơn hàng cho thấy hành vi mua sắm trên Olist chủ yếu là mua đơn lẻ, với hơn 75% đơn hàng chỉ chứa một sản phẩm. Do đó, các chiến lược bán kèm (bundle) dựa trên hành vi mua đồng thời trong cùng một đơn hàng không mang lại hiệu quả rõ rệt.

# %% [markdown]
# ## 2.3. Chiến lược giá và khuyến mãi
#
# Giá sản phẩm ảnh hưởng thế nào đến doanh thu?
#
# Chương trình khuyến mãi nào thực sự tăng doanh thu, không chỉ giảm giá?
#
# Có thể áp dụng dynamic pricing theo khu vực hoặc thời điểm để tăng doanh thu không?

# %%
price_bins = [0, 50, 200, 500, 1000, data['price'].max()]
price_labels = ['<50', '50-200', '200-500', '500-1000', '>1000']

data['price_band'] = pd.cut(
    data['price'],
    bins=price_bins,
    labels=price_labels,
    include_lowest=True
)

# %%
price_analysis = data.groupby('price_band').agg(
    total_revenue=('order_value', 'sum'),
    num_orders=('order_id', 'nunique'),
    avg_order_value=('order_value', 'mean')
).reset_index()

price_analysis
# Out:
# C:\Users\biena\AppData\Local\Temp\ipykernel_19644\3792186907.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_analysis = data.groupby('price_band').agg(
#   price_band  total_revenue  num_orders  avg_order_value
# 0        <50     1779463.25       32285        46.219825
# 1     50-200     7388330.03       52210       126.020503
# 2    200-500     3213841.35        9270       327.275087
# 3   500-1000     1662646.16        2181       735.358762
# 4      >1000     1316333.98         778      1639.270212

# %% [markdown]
# Phân khúc giá 50–200
#
# Đóng góp lớn nhất (~45–50% tổng doanh thu)
#
# Có số đơn hàng cao nhất
#
# Giá càng cao → AOV tăng mạnh, nhưng:
#
# Số đơn giảm rất nhanh
#
# Tổng doanh thu không tăng tương ứng
#
# Kết luận
#
# Doanh thu không tăng tuyến tính theo giá. Phân khúc trung cấp (50–200) mang lại hiệu quả doanh thu tốt nhất nhờ cân bằng giữa số lượng đơn và giá trị đơn hàng.

# %%
data['freight_ratio'] = data['freight_value'] / data['price']

ship_bins = [0, 0.1, 0.3, 0.6, data['freight_ratio'].max()]
ship_labels = ['Low', 'Medium', 'High', 'Very High']

data['shipping_level'] = pd.cut(
    data['freight_ratio'],
    bins=ship_bins,
    labels=ship_labels,
    include_lowest=True
)

shipping_analysis = data.groupby('shipping_level').agg(
    total_revenue=('order_value', 'sum'),
    num_orders=('order_id', 'nunique'),
    avg_order_value=('order_value', 'mean')
).reset_index()

shipping_analysis
# Out:
# C:\Users\biena\AppData\Local\Temp\ipykernel_19644\2733768199.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   shipping_analysis = data.groupby('shipping_level').agg(
#   shipping_level  total_revenue  num_orders  avg_order_value
# 0            Low     5921476.20       15751       349.287807
# 1         Medium     6747559.87       47274       127.833432
# 2           High     2070678.47       23460        75.921334
# 3      Very High      620900.23       10915        47.757882

# %% [markdown]
# Phí ship thấp / trung bình → doanh thu cao hơn rõ rệt
#
# Phí ship cao:
#
# AOV thấp
#
# Khách mua nhiều đơn nhỏ → kém hiệu quả
#
# Chiến lược khuyến mãi hiệu quả
#
# Free ship theo ngưỡng giá (ví dụ >150)
#
# Giảm phí ship thay vì giảm giá sản phẩm
#
# Tránh giảm giá sâu cho sản phẩm giá thấp (biên lợi nhuận thấp)
#
# Kết luận
#
# Khuyến mãi hiệu quả nhất không phải là giảm giá sản phẩm, mà là tối ưu chi phí vận chuyển để tăng giá trị đơn hàng trung bình.

# %%
state_analysis = data.groupby('customer_state').agg(
    total_revenue=('order_value', 'sum'),
    num_orders=('order_id', 'nunique'),
    avg_price=('price', 'mean'),
    avg_freight=('freight_value', 'mean')
).reset_index().sort_values('total_revenue', ascending=False)

state_analysis.head(10)
# Out:
#    customer_state  total_revenue  num_orders   avg_price  avg_freight
# 25             SP     5766150.08       40267  109.084095    15.114110
# 18             RJ     2034914.18       12214  123.896721    20.895807
# 10             MG     1811774.44       11286  119.785726    20.596611
# 22             RS      862729.70        5326  118.423786    21.584279
# 17             PR      782745.65        4900  118.086756    20.501354
# 4              BA      589223.13        3229  134.102706    26.492314
# 23             SC      588524.94        3520  122.786048    21.495624
# 6              DF      347244.68        2070  125.815554    21.073058
# 8              GO      333498.43        1946  124.766786    22.668417
# 15             PE      308163.59        1579  144.383161    32.722351

# %% [markdown]
# SP, RJ, MG:
#
# Doanh thu cao
#
# Phí ship thấp
#
# Giá trung bình ổn định
#
# Có thể:
#
# Giữ giá cao hơn một chút
#
# Giảm ưu đãi → vẫn giữ được cầu
#
# Các bang như PE, BA:
#
# Phí ship cao
#
# Giá trung bình cao nhưng doanh thu thấp
#
# Nên:
#
# Giảm giá nhẹ
#
# Hoặc trợ giá ship

# %%
data['order_purchase_timestamp'] = pd.to_datetime(data['order_purchase_timestamp'])

data['purchase_month'] = data['order_purchase_timestamp'].dt.month
data['purchase_year'] = data['order_purchase_timestamp'].dt.year

monthly_revenue = data.groupby(['purchase_year','purchase_month']).agg(
    total_revenue=('order_value', 'sum'),
    num_orders=('order_id', 'nunique'),
    avg_price=('price', 'mean')
).reset_index()

monthly_revenue
# Out:
#     purchase_year  purchase_month  total_revenue  num_orders   avg_price
# 0            2016               9         143.46           1   44.990000
# 1            2016              10       46556.01         267  126.555298
# 2            2016              12          19.62           1   10.900000
# 3            2017               1      127156.98         741  121.920164
# 4            2017               2      271241.08        1643  126.032824
# 5            2017               3      409893.44        2527  122.737835
# 6            2017               4      388755.80        2290  132.279165
# 7            2017               5      565707.33        3517  121.625315
# 8            2017               6      491104.33        3111  120.818068
# 9            2017               7      564738.23        3842  108.462671
# 10           2017               8      644348.90        4165  115.323953
# 11           2017               9      699528.40        4118  127.947458
# 12           2017              10      748085.24        4446  123.845133
# 13           2017              11     1151417.97        7237  116.461645
# 14           2017              12      834821.36        5461  116.897053
# 15           2018               1     1073517.83        7013  114.834017
# 16           2018               2      969715.44        6508  109.839433
# 17           2018               3     1113708.32        6948  118.336193
# 18           2018               4     1128670.42        6752  124.698622
# 19           2018               5     1123279.31        6722  125.068041
# 20           2018               6     1009743.18        6072  122.445513
# 21           2018               7     1016635.70        6118  123.623612
# 22           2018               8      981826.42        6330  117.323928

# %% [markdown]
# Doanh thu tăng mạnh:
#
# Q4/2017
#
# Đầu 2018
#
# Giá trung bình không tăng nhiều
#
# Gợi ý:
#
# Mùa cao điểm: tăng giá nhẹ (2–5%)
#
# Mùa thấp điểm: combo / voucher kích cầu

# %%
price_by_customer = data.groupby(['Customer_Label','price_band']).agg(
    total_revenue=('order_value','sum'),
    num_orders=('order_id','nunique')
).reset_index()

price_by_customer
# Out:
# C:\Users\biena\AppData\Local\Temp\ipykernel_19644\4111441023.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_by_customer = data.groupby(['Customer_Label','price_band']).agg(
#    Customer_Label price_band  total_revenue  num_orders
# 0         At Risk        <50      701169.07       12801
# 1         At Risk     50-200     2797212.61       20579
# 2         At Risk    200-500     1272476.91        3874
# 3         At Risk   500-1000      202662.32         329
# 4         At Risk      >1000           0.00           0
# 5           Loyal        <50      130423.74        2157
# 6           Loyal     50-200      479361.37        3151
# 7           Loyal    200-500      179489.87         501
# 8           Loyal   500-1000       43304.60          60
# 9           Loyal      >1000        7150.93           5
# 10            New        <50      945897.09       17310
# 11            New     50-200     3957766.36       28284
# 12            New    200-500     1568859.95        4679
# 13            New   500-1000      286971.87         486
# 14            New      >1000           0.00           0
# 15            VIP        <50        1973.35          17
# 16            VIP     50-200      153989.69         196
# 17            VIP    200-500      193014.62         216
# 18            VIP   500-1000     1129707.37        1306
# 19            VIP      >1000     1309183.05         773

# %% [markdown]
# VIP
#
# Gần như toàn bộ doanh thu >1000 là từ VIP
#
# Rất mạnh ở 500–1000 và >1000
#
# Chiến lược:
#
# Không giảm giá
#
# Ưu tiên dịch vụ, giao nhanh
#
# Loyal
#
# Tập trung 50–200
#
# Rất ít mua giá cao
#
# Chiến lược:
#
# Combo
#
# Upsell sang 200–500
#
# New / At Risk
#
# Mua nhiều ở <200
#
# Nhạy cảm giá
#
# Chiến lược:
#
# Voucher lần đầu
#
# Free ship

# %% [markdown]
# Doanh thu chịu ảnh hưởng mạnh bởi phân khúc giá, chi phí vận chuyển, khu vực và nhóm khách hàng. Phân khúc giá trung cấp (50–200) là trụ cột doanh thu, trong khi khách hàng VIP mang lại doanh thu cao ở phân khúc giá cao. Do đó, doanh nghiệp có thể áp dụng dynamic pricing theo khu vực, thời điểm và phân khúc khách hàng nhằm tối ưu doanh thu thay vì áp dụng một mức giá cố định.

# %%
price_analysis.to_csv('price_analysis.csv', index=False)
shipping_analysis.to_csv('shipping_analysis.csv', index=False)
state_analysis.to_csv('state_analysis.csv', index=False)
monthly_revenue.to_csv('monthly_revenue.csv', index=False)
